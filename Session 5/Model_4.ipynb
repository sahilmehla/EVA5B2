# %% [markdown]
# # Import Libraries

# %%
from __future__ import print_function
import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
from torchvision import datasets, transforms

# %% [markdown]
# ## Data Transformations
#
# We first start with defining our data transformations. We need to think what our data is and how can we augment it to correct represent images which it might not see otherwise.

# %%
# Train Phase transformations
train_transforms = transforms.Compose([
                                      #  transforms.Resize((28, 28)),
                                      #  transforms.ColorJitter(brightness=0.10, contrast=0.1, saturation=0.10, hue=0.1),
                                       #transforms.RandomRotation((-7.0, 7.0), fill=(1,)),
                                       transforms.RandomAffine(degrees=(-10.0, 10.0), translate=(0.1, 0.1), scale=(0.8, 1.2)),
                                       transforms.ToTensor(),
                                       transforms.Normalize((0.1307,), (0.3081,)) # The mean and std have to be sequences (e.g., tuples), therefore you should add a comma after the values. 
                                       # Note the difference between (0.1307) and (0.1307,)
                                       ])

# Test Phase transformations
test_transforms = transforms.Compose([
                                      #  transforms.Resize((28, 28)),
                                      #  transforms.ColorJitter(brightness=0.10, contrast=0.1, saturation=0.10, hue=0.1),
                                       transforms.ToTensor(),
                                       transforms.Normalize((0.1307,), (0.3081,))
                                       ])

# %% [markdown]
# # Dataset and Creating Train/Test Split

# %%
train = datasets.MNIST('./data', train=True, download=True, transform=train_transforms)
test = datasets.MNIST('./data', train=False, download=True, transform=test_transforms)

# %% [markdown]
# # Dataloader Arguments & Test/Train Dataloaders

# %%
SEED = 1

# CUDA?
cuda = torch.cuda.is_available()
print("CUDA Available?", cuda)

# For reproducibility
torch.manual_seed(SEED)

if cuda:
    torch.cuda.manual_seed(SEED)

# dataloader arguments - something you'll fetch these from cmdprmt
dataloader_args = dict(shuffle=True, batch_size=128, num_workers=4, pin_memory=True) if cuda else dict(shuffle=True, batch_size=64)

# train dataloader
train_loader = torch.utils.data.DataLoader(train, **dataloader_args)

# test dataloader
test_loader = torch.utils.data.DataLoader(test, **dataloader_args)
# Out:
# CUDA Available? True

# %% [markdown]
# # The model
# Let's start with the model we first saw

# %%
dropout_value=0

class Net(nn.Module):
    def __init__(self):
        super(Net, self).__init__()
        
        self.conv1 = nn.Sequential(
            nn.Conv2d(1, 7, 3, padding=0, bias=0),     #Input-1x28x28      Output-7x26x26    RF-3
            nn.ReLU(),
            nn.BatchNorm2d(7),
            nn.Dropout(dropout_value),
            nn.Conv2d(7, 14, 3, padding=0, bias=0),    #Input-7x26x26      Output-14x24x24    RF-5
            nn.ReLU(),
            nn.BatchNorm2d(14),
            nn.Dropout(dropout_value),

            nn.Conv2d(14, 7, 1),                       #Input-14x24x24     Output-7x24x24    RF-10
            nn.MaxPool2d(2, 2)                          #Input-7x24x24     Output-7x12x12    RF-10
            
            
        )
        
        self.conv2 = nn.Sequential(
            nn.Conv2d(7, 14, 3, padding=0, bias=0),    #Input-7x12x12        Output-14x10x10    RF-12
            nn.ReLU(),
            nn.BatchNorm2d(14),
            nn.Dropout(dropout_value),
            nn.Conv2d(14, 28, 3, padding=1, bias=0),    #Input-14x10x10      Output-28x10x10      RF-14
            nn.ReLU(),
            nn.BatchNorm2d(28),
            nn.Dropout(dropout_value),

            nn.Conv2d(28, 14, 1),                       #Input-28x10x10      Output-14x10x10    RF-28
            nn.MaxPool2d(2, 2)                          #Input-14x10x10      Output-14x5x5    RF-28 
        )
        
        self.conv3 = nn.Sequential(
            nn.Conv2d(14, 21, 3, padding=1, bias=0),    #Input-14x5x5    Output-21x5x5    RF-30
            nn.ReLU(),
            nn.BatchNorm2d(21),
            nn.Dropout(dropout_value),

            nn.Conv2d(21, 40, 1)                        #Input-21x5x5    Output-40x5x5    RF-30 
        )
        
        self.avgpool = nn.AvgPool2d(5)                  #Input-40x5x5    Output-40x1x1

        self.out = nn.Sequential(
            nn.Conv2d(40, 10, 1, bias=0)                #Input-40x1x1    Output-10x1x1
        )        
        
    def forward(self, x):
        x = self.conv1(x)
        x = self.conv2(x)
        x = self.conv3(x)
        x = self.avgpool(x)
        x = self.out(x)
        x = x.squeeze()
        x = F.log_softmax(x, dim=1)
        return x

# %% [markdown]
# # Model Params
# Can't emphasize on how important viewing Model Summary is.
# Unfortunately, there is no in-built model visualizer, so we have to take external help

# %%
# !pip install torchsummary
from torchsummary import summary
use_cuda = torch.cuda.is_available()
device = torch.device("cuda" if use_cuda else "cpu")
print(device)
model = Net().to(device)
summary(model, input_size=(1, 28, 28))
# Out:
# Requirement already satisfied: torchsummary in /home/sahil/miniconda3/envs/deeplearning/lib/python3.8/site-packages (1.5.1)
# WARNING: You are using pip version 20.2.4; however, version 20.3.3 is available.
# You should consider upgrading via the '/home/sahil/miniconda3/envs/deeplearning/bin/python -m pip install --upgrade pip' command.
# cuda
# ----------------------------------------------------------------
#         Layer (type)               Output Shape         Param #
# ================================================================
#             Conv2d-1            [-1, 7, 26, 26]              63
#               ReLU-2            [-1, 7, 26, 26]               0
#        BatchNorm2d-3            [-1, 7, 26, 26]              14
#            Dropout-4            [-1, 7, 26, 26]               0
#             Conv2d-5           [-1, 14, 24, 24]             882
#               ReLU-6           [-1, 14, 24, 24]               0
#        BatchNorm2d-7           [-1, 14, 24, 24]              28
#            Dropout-8           [-1, 14, 24, 24]               0
#             Conv2d-9            [-1, 7, 24, 24]             105
#         MaxPool2d-10            [-1, 7, 12, 12]               0
#            Conv2d-11           [-1, 14, 10, 10]             882
#              ReLU-12           [-1, 14, 10, 10]               0
#       BatchNorm2d-13           [-1, 14, 10, 10]              28
#           Dropout-14           [-1, 14, 10, 10]               0
#            Conv2d-15           [-1, 28, 10, 10]           3,528
#              ReLU-16           [-1, 28, 10, 10]               0
#       BatchNorm2d-17           [-1, 28, 10, 10]              56
#           Dropout-18           [-1, 28, 10, 10]               0
#            Conv2d-19           [-1, 14, 10, 10]             406
#         MaxPool2d-20             [-1, 14, 5, 5]               0
#            Conv2d-21             [-1, 21, 5, 5]           2,646
#              ReLU-22             [-1, 21, 5, 5]               0
#       BatchNorm2d-23             [-1, 21, 5, 5]              42
#           Dropout-24             [-1, 21, 5, 5]               0
#            Conv2d-25             [-1, 40, 5, 5]             880
#         AvgPool2d-26             [-1, 40, 1, 1]               0
#            Conv2d-27             [-1, 10, 1, 1]             400
# ================================================================
# Total params: 9,960
# Trainable params: 9,960
# Non-trainable params: 0
# ----------------------------------------------------------------
# Input size (MB): 0.00
# Forward/backward pass size (MB): 0.59
# Params size (MB): 0.04
# Estimated Total Size (MB): 0.64
# ----------------------------------------------------------------

# %% [markdown]
# # Training and Testing
#
# Looking at logs can be boring, so we'll introduce **tqdm** progressbar to get cooler logs.
#
# Let's write train and test functions

# %%
from tqdm import tqdm

train_losses = []
test_losses = []
train_acc = []
test_acc = []

def train(model, device, train_loader, optimizer, epoch):
  model.train()
  pbar = tqdm(train_loader)
  correct = 0
  processed = 0
  for batch_idx, (data, target) in enumerate(pbar):
    # get samples
    data, target = data.to(device), target.to(device)

    # Init
    optimizer.zero_grad()
    # In PyTorch, we need to set the gradients to zero before starting to do backpropragation because PyTorch accumulates the gradients on subsequent backward passes. 
    # Because of this, when you start your training loop, ideally you should zero out the gradients so that you do the parameter update correctly.

    # Predict
    y_pred = model(data)

    # Calculate loss
    loss = F.nll_loss(y_pred, target)
    train_losses.append(loss)

    # Backpropagation
    loss.backward()
    optimizer.step()

    # Update pbar-tqdm
    
    pred = y_pred.argmax(dim=1, keepdim=True)  # get the index of the max log-probability
    correct += pred.eq(target.view_as(pred)).sum().item()
    processed += len(data)

    pbar.set_description(desc= f'Loss={loss.item()} Batch_id={batch_idx} Accuracy={100*correct/processed:0.2f}')
    train_acc.append(100*correct/processed)

def test(model, device, test_loader):
    model.eval()
    test_loss = 0
    correct = 0
    with torch.no_grad():
        for data, target in test_loader:
            data, target = data.to(device), target.to(device)
            output = model(data)
            test_loss += F.nll_loss(output, target, reduction='sum').item()  # sum up batch loss
            pred = output.argmax(dim=1, keepdim=True)  # get the index of the max log-probability
            correct += pred.eq(target.view_as(pred)).sum().item()

    test_loss /= len(test_loader.dataset)
    test_losses.append(test_loss)

    print('\nTest set: Average loss: {:.4f}, Accuracy: {}/{} ({:.2f}%)\n'.format(
        test_loss, correct, len(test_loader.dataset),
        100. * correct / len(test_loader.dataset)))
    
    test_acc.append(100. * correct / len(test_loader.dataset))

# %%
from torch.optim.lr_scheduler import StepLR

model =  Net().to(device)
optimizer = optim.SGD(model.parameters(), lr=0.01, momentum=0.9)
#scheduler = optim.lr_scheduler.ReduceLROnPlateau(
#    optimizer, patience=10, verbose=True)
scheduler = StepLR(optimizer, step_size=5, gamma=0.1)


EPOCHS = 15
for epoch in range(EPOCHS):
    print("EPOCH:", epoch)
    train(model, device, train_loader, optimizer, epoch)
    scheduler.step()
    test(model, device, test_loader)
# Out:
#   0%|          | 0/469 [00:00<?, ?it/s]EPOCH: 0
# Loss=0.20062582194805145 Batch_id=468 Accuracy=75.93: 100%|██████████| 469/469 [00:03<00:00, 119.28it/s]
#   0%|          | 0/469 [00:00<?, ?it/s]
# Test set: Average loss: 0.1242, Accuracy: 9625/10000 (96.25%)
#
# EPOCH: 1
# Loss=0.12186861783266068 Batch_id=468 Accuracy=95.81: 100%|██████████| 469/469 [00:04<00:00, 115.11it/s]
#   0%|          | 0/469 [00:00<?, ?it/s]
# Test set: Average loss: 0.0553, Accuracy: 9835/10000 (98.35%)
#
# EPOCH: 2
# Loss=0.0288156196475029 Batch_id=468 Accuracy=96.94: 100%|██████████| 469/469 [00:04<00:00, 117.23it/s]
#   0%|          | 0/469 [00:00<?, ?it/s]
# Test set: Average loss: 0.0557, Accuracy: 9821/10000 (98.21%)
#
# EPOCH: 3
# Loss=0.15457715094089508 Batch_id=468 Accuracy=97.44: 100%|██████████| 469/469 [00:04<00:00, 113.00it/s]
#   0%|          | 0/469 [00:00<?, ?it/s]
# Test set: Average loss: 0.0403, Accuracy: 9861/10000 (98.61%)
#
# EPOCH: 4
# Loss=0.042575616389513016 Batch_id=468 Accuracy=97.72: 100%|██████████| 469/469 [00:04<00:00, 116.20it/s]
#   0%|          | 0/469 [00:00<?, ?it/s]
# Test set: Average loss: 0.0336, Accuracy: 9895/10000 (98.95%)
#
# EPOCH: 5
# Loss=0.15776871144771576 Batch_id=468 Accuracy=98.29: 100%|██████████| 469/469 [00:04<00:00, 115.17it/s]
#   0%|          | 0/469 [00:00<?, ?it/s]
# Test set: Average loss: 0.0218, Accuracy: 9932/10000 (99.32%)
#
# EPOCH: 6
# Loss=0.03630206361413002 Batch_id=468 Accuracy=98.38: 100%|██████████| 469/469 [00:04<00:00, 112.62it/s]
#   0%|          | 0/469 [00:00<?, ?it/s]
# Test set: Average loss: 0.0219, Accuracy: 9936/10000 (99.36%)
#
# EPOCH: 7
# Loss=0.06193934381008148 Batch_id=468 Accuracy=98.46: 100%|██████████| 469/469 [00:03<00:00, 118.85it/s]
#   0%|          | 0/469 [00:00<?, ?it/s]
# Test set: Average loss: 0.0210, Accuracy: 9934/10000 (99.34%)
#
# EPOCH: 8
# Loss=0.0185882318764925 Batch_id=468 Accuracy=98.49: 100%|██████████| 469/469 [00:04<00:00, 116.72it/s]
#   0%|          | 0/469 [00:00<?, ?it/s]
# Test set: Average loss: 0.0200, Accuracy: 9940/10000 (99.40%)
#
# EPOCH: 9
# Loss=0.03716953843832016 Batch_id=468 Accuracy=98.46: 100%|██████████| 469/469 [00:04<00:00, 115.26it/s]
#   0%|          | 0/469 [00:00<?, ?it/s]
# Test set: Average loss: 0.0196, Accuracy: 9941/10000 (99.41%)
#
# EPOCH: 10
# Loss=0.0632353201508522 Batch_id=468 Accuracy=98.43: 100%|██████████| 469/469 [00:04<00:00, 113.48it/s]
#   0%|          | 0/469 [00:00<?, ?it/s]
# Test set: Average loss: 0.0191, Accuracy: 9940/10000 (99.40%)
#
# EPOCH: 11
# Loss=0.010517306625843048 Batch_id=468 Accuracy=98.59: 100%|██████████| 469/469 [00:04<00:00, 112.51it/s]
#   0%|          | 0/469 [00:00<?, ?it/s]
# Test set: Average loss: 0.0197, Accuracy: 9940/10000 (99.40%)
#
# EPOCH: 12
# Loss=0.10079721361398697 Batch_id=468 Accuracy=98.53: 100%|██████████| 469/469 [00:04<00:00, 115.60it/s]
#   0%|          | 0/469 [00:00<?, ?it/s]
# Test set: Average loss: 0.0194, Accuracy: 9941/10000 (99.41%)
#
# EPOCH: 13
# Loss=0.03634319081902504 Batch_id=468 Accuracy=98.55: 100%|██████████| 469/469 [00:04<00:00, 116.65it/s]
#   0%|          | 0/469 [00:00<?, ?it/s]
# Test set: Average loss: 0.0194, Accuracy: 9941/10000 (99.41%)
#
# EPOCH: 14
# Loss=0.0436113215982914 Batch_id=468 Accuracy=98.53: 100%|██████████| 469/469 [00:04<00:00, 116.65it/s]
#
# Test set: Average loss: 0.0192, Accuracy: 9943/10000 (99.43%)

# %% [markdown]
# # Let's Train and test our model
#
# This time let's add a scheduler for out LR.

# %%
# %matplotlib inline
import matplotlib.pyplot as plt

fig, axs = plt.subplots(2,2,figsize=(15,10))
axs[0, 0].plot(train_losses)
axs[0, 0].set_title("Training Loss")
axs[1, 0].plot(train_acc[4000:])
axs[1, 0].set_title("Training Accuracy")
axs[0, 1].plot(test_losses)
axs[0, 1].set_title("Test Loss")
axs[1, 1].plot(test_acc)
axs[1, 1].set_title("Test Accuracy")
# Out:
# Text(0.5, 1.0, 'Test Accuracy')
